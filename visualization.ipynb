# %% [markdown]
# # Visualization

# %%
import pandas as pd
# import plotly.express as px
# import plotly.graph_objects as go


katalog = pd.read_csv('katalog_gempa.tsv', sep='\t')

# %%
katalog.fillna('')
# Out:
#               tgl            ot   lat     lon  depth  mag  \
# 0      2010/03/02  23:41:57.804  3.74  127.08     45  4.7
# 1      2010/03/02  23:41:30.530  0.75   99.68     10  3.1
# 2      2010/03/02  23:23:29.343  0.92  120.09     10  3.5
# 3      2010/03/02  22:46:07.861  0.35  120.64     10  3.4
# 4      2010/03/02  22:33:34.591  1.52   97.35     28  3.4
# ...           ...           ...   ...     ...    ...  ...
# 40972  2010/12/28  16:00:59.742 -5.00  103.12     34  3.9
# 40973  2010/12/28  14:09:03.564  4.47   96.22     10  3.3
# 40974  2010/12/28  06:58:43.983 -7.24  107.44     10  3.4
# 40975  2010/12/28  04:28:40.256 -7.16  107.75    302  3.8
# 40976  2010/12/28  04:02:08.125 -1.27  120.43     27  3.8
#
#                               remark strike1 dip1 rake1 strike2 dip2 rake2
# 0          Talaud Islands- Indonesia
# 1        Northern Sumatra- Indonesia
# 2      Minahassa Peninsula- Sulawesi
# 3      Minahassa Peninsula- Sulawesi
# 4        Northern Sumatra- Indonesia
# ...

# %%
# Distribusi magnitudo gempa
katalog.groupby('mag').count()['remark'].plot(figsize=(16, 4));
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Frekuensi banyak gempa berdasarkan waktu
katalog.groupby('tgl').count()['remark'].plot(figsize=(16, 4));

# %%
# Mean gempa berdasarkan waktu
katalog.groupby('tgl').mean()['mag'].plot(figsize=(16, 4));

# %%
# diagram pencar

# fig = px.scatter_mapbox(katalog, lat='lat', lon='lon', color='mag',
#                         hover_data=['tgl', 'ot', 'depth'], zoom=4,
#                         mapbox_style="open-street-map")

# fig.show(renderer="notebook")

# %%
# 3D plot

# df = katalog.copy()
# df['depth'] = -df['depth']
# df['lon'] = -df['lon']

# fig = px.scatter_3d(df, x='lat', y='lon', z='depth',
#                     color='mag', size='mag',
#                     size_max=10, opacity=0.7)

# fig.update_layout(height=600,
#                   scene=dict(aspectratio={'x':4, 'y':10, 'z':3}),
#                   scene_camera=dict(eye=dict(x=0., y=0., z=7.)))
# fig.update_traces(marker=dict(line=dict(width=0)),
#                   selector=dict(mode='markers'))

# fig.show(renderer="notebook")
